# %% [markdown]
# ## import & load google drive

# %%
import pandas as pd
import numpy as np

# google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # config

# %%
path = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/sp500/MMM/MMM_OHLC_1d.csv"

# %% [markdown]
# # read data with pandas.DataFrame

# %%
raw_df = pd.read_csv(path)
raw_df.head(10)
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2017-01-03 00:00:00-05:00  149.337611  150.314655  147.993130  148.686249
# 1  2017-01-04 00:00:00-05:00  148.669517  149.396033  148.318784  148.911697
# 2  2017-01-05 00:00:00-05:00  148.861582  149.596458  147.717525  148.402298
# 3  2017-01-06 00:00:00-05:00  148.051524  149.145491  146.807261  148.836502
# 4  2017-01-09 00:00:00-05:00  148.953371  148.961730  147.976328  148.034790
# 5  2017-01-10 00:00:00-05:00  148.109996  148.218560  147.233158  147.458633
# 6  2017-01-11 00:00:00-05:00  147.500384  149.020225  147.299960  148.552582
# 7  2017-01-12 00:00:00-05:00  147.784299  148.393905  146.765499  148.176788
# 8  2017-01-13 00:00:00-05:00  148.293738  148.569317  147.667427  148.135071
# 9  2017-01-17 00:00:00-05:00  147.809357  148.377207  147.183047  148.026474
#
#     Volume
# 0  2509300
# 1  1542000
# 2  1447800
# 3  1625000
# 4  1622600
# 5  2030100
# 6  1579600
# 7  1321800
# 8  1265500
# 9  1557500

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1447 entries, 0 to 1446
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1447 non-null   object
#  1   Open    1447 non-null   float64
#  2   High    1447 non-null   float64
#  3   Low     1447 non-null   float64
#  4   Close   1447 non-null   float64
#  5   Volume  1447 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 68.0+ KB

# %% [markdown]
# # convert ‘Date’ into datatime

# %%
def drop_hours(row):
  row = row.split(' ')[0]
  return row

# %%
raw_df['Date'] = raw_df['Date'].apply(drop_hours)

# %% [markdown]
# convert "Date" into datatime type

# %%
raw_df['Date'] = pd.to_datetime(raw_df['Date'])

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1447 entries, 0 to 1446
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1447 non-null   datetime64[ns]
#  1   Open    1447 non-null   float64
#  2   High    1447 non-null   float64
#  3   Low     1447 non-null   float64
#  4   Close   1447 non-null   float64
#  5   Volume  1447 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 68.0 KB

# %%
display(raw_df.Date.min())
display(raw_df.Date.max())
# Out:
# Timestamp('2017-01-03 00:00:00')
# Timestamp('2022-09-30 00:00:00')

# %% [markdown]
# create empty dataFrame

# %%
df = pd.DataFrame(columns=['stock','weekNo','days','成交量均值','成交金额均值','上周涨跌幅','涨跌幅均值','股价波动程度','开收盘价方差','未来一周的收益率'])

# %% [markdown]
# # get features

# %%
start_date = '2017-1-2'
end_date = '2022-9-30'

week = pd.Period('2017-1-2', freq='W')

last_week = float('inf')

# %%
count = 0
while week.start_time < pd.to_datetime(end_date):

  record = dict()
  # record['start_time'] = week.start_time
  # record['end_time'] = week.end_time
  count += 1
  record['weekNo'] = count

  # get dates in current week
  mask = (raw_df['Date'] >= week.start_time) & (raw_df['Date'] < week.end_time)
  df_week = raw_df.loc[mask]

  # drop the index (important)
  df_week = df_week.reset_index(drop=True)

  # count days
  n_days = df_week.shape[0]
  record['days'] = df_week.shape[0]

  # 成交量均值
  record['成交量均值'] = df_week['Volume'].mean()

  # 成交金额均值
  record['成交金额均值'] = (df_week['Volume']*df_week['Close']).mean()

  # 上周涨跌幅 = (end..price - start.rice) / start.price
  if last_week == 'inf':
    record['上周涨跌幅'] = np.nan
  else:
    record['上周涨跌幅'] = last_week

  # 涨跌幅均值 = 涨跌幅/开盘日
  record['涨跌幅均值'] = ((df_week['Close'][df_week.shape[0]-1] - df_week['Close'][0]) / df_week['Close'][0]) / n_days
  last_week = (df_week['Close'][df_week.shape[0]-1] - df_week['Close'][0]) / df_week['Close'][0]

  # 股价波动程度 = 标准差/平均值
  record['股价波动程度'] = df_week['Close'].std() / df_week['Close'].mean()

  # 开盘价，收盘价方差 = 开盘价方差+收盘价方差
  record['开收盘价方差'] = df_week['Close'].var() + df_week['Open'].var()

  # 未来一周的收益率 = (一周后收盘价格-当前收盘价格)/当前收盘价
  next_week = week + 1
  mask = (raw_df['Date'] >= next_week.start_time) & (raw_df['Date'] < next_week.end_time)
  df_next_week = raw_df.loc[mask]
  df_next_week = df_next_week.reset_index(drop=True)
  cur_close = df_week['Close'][df_week.shape[0]-1]
  if df_next_week.shape[0] != 0:
    record['未来一周的收益率'] = (df_next_week['Close'][df_next_week.shape[0]-1] - cur_close) / cur_close

  record['stock'] = "AAPL"

  df = df.append([record],ignore_index=True)

  week += 1

# %%
df
# Out:
#     stock weekNo days       成交量均值        成交金额均值     上周涨跌幅     涨跌幅均值    股价波动程度  \
# 0    AAPL      1    4   1781025.0  2.648591e+08       inf  0.000253  0.001513
# 1    AAPL      2    5   1563920.0  2.315071e+08  0.001011  0.000135  0.002666
# 2    AAPL      3    4   1647100.0  2.451644e+08  0.000677  0.001735  0.003663
# 3    AAPL      4    5   2556440.0  3.776762e+08  0.006939 -0.001154  0.005375
# 4    AAPL      5    5   2373760.0  3.466297e+08 -0.005770 -0.000433  0.002688
# ..    ...    ...  ...         ...           ...       ...       ...       ...
# 295  AAPL    296    5  31997600.0  4.004827e+09 -0.087930 -0.007577  0.014624
# 296  AAPL    297    4  30065950.0  3.602579e+09 -0.037884  0.013937  0.022563
# 297  AAPL    298    5   8744500.0  1.055570e+09  0.055746 -0.012298  0.027933
# 298  AAPL    299    5   3688500.0  4.242319e+08 -0.061489 -0.006259  0.013618
# 299  AAPL    300    5   3205620.0  3.609040e+08 -0.031293 -0.004425  0.012145
#
#         开收盘价方差  未来一周的收益率
# 0     0.334140 -0.004713
# 1     0.461146  0.006201
# 2     1.124048 -0.005659
# 3     0.886468 -0.013748
# 4     1.349654  0.022623
# ..         ...       ...
# 295   6.479938  0.011919
# 296  12.641034 -0.052721
# 297  25.124960 -0.031044
# 298   4.094778 -0.022037
# 299   2.509187       NaN
#
# [300 rows x 10 columns]

# %%
info  = pd.read_csv('/content/drive/MyDrive/BDT SEM 1/MSBD 5001/sp500/AAPL/AAPL_info.csv')
info = info.set_index('Attribute')

# %% [markdown]
# # Whole pipeline

# %%
import pandas as pd
import numpy as np
import os

# google drive
from google.colab import drive
drive.mount('/content/drive') 

# ROOT
root = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/sp500/"

# save
save = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/Data Preprocessing/dataset"

# file name
file_name = "weekdate_2211171705.csv"

os.chdir(root)
os.listdir(root)

dirs = os.listdir()
# Out:
# Mounted at /content/drive

# %%
df = pd.DataFrame(columns=['name','stock','start_time','end_time','days','成交量均值','成交金额均值','上周涨跌幅','涨跌幅均值','股价波动程度','开收盘价方差','未来一周的收益率'])

# %%
def drop_hours(row):
  row = row.split(' ')[0]
  return row

# %%
def get_features(df, raw_df, name, stock):

  # start and end
  start_date = '2017-1-2'
  end_date = '2022-9-30'

  # first week
  week = pd.Period(start_date, freq='W')

  last_week = float('inf')  

  while week.start_time < pd.to_datetime(end_date):

    record = dict()

    record['start_time'] = week.start_time
    record['end_time'] = week.end_time

    # get dates in current week
    mask = (raw_df['Date'] >= week.start_time) & (raw_df['Date'] < week.end_time)
    df_week = raw_df.loc[mask]
    #if df_week.shape[0] == 0:
    #  week += 1
    #  continue

    # drop the index (important)
    df_week = df_week.reset_index(drop=True)

    # count days
    n_days = df_week.shape[0]
    record['days'] = df_week.shape[0]

    # 成交量均值
    record['成交量均值'] = df_week['Volume'].mean()

    # 成交金额均值
    record['成交金额均值'] = (df_week['Volume']*df_week['Close']).mean()

    # 上周涨跌幅 = (end..price - start.rice) / start.price
    if last_week == 'inf':
      record['上周涨跌幅'] = np.nan
    else:
      record['上周涨跌幅'] = last_week

    # 涨跌幅均值 = 涨跌幅/开盘日
    record['涨跌幅均值'] = ((df_week['Close'][df_week.shape[0]-1] - df_week['Close'][0]) / df_week['Close'][0]) / n_days
    last_week = (df_week['Close'][df_week.shape[0]-1] - df_week['Close'][0]) / df_week['Close'][0]

    # 股价波动程度 = 标准差/平均值
    record['股价波动程度'] = df_week['Close'].std() / df_week['Close'].mean()

    # 开盘价，收盘价方差 = 开盘价方差+收盘价方差
    record['开收盘价方差'] = df_week['Close'].var() + df_week['Open'].var()

    # 未来一周的收益率 = (一周后收盘价格-当前收盘价格)/当前收盘价
    next_week = week + 1
    mask = (raw_df['Date'] >= next_week.start_time) & (raw_df['Date'] < next_week.end_time)
    df_next_week = raw_df.loc[mask]
    df_next_week = df_next_week.reset_index(drop=True)
    cur_close = df_week['Close'][df_week.shape[0]-1]
    if df_next_week.shape[0] != 0:
      record['未来一周的收益率'] = (df_next_week['Close'][df_next_week.shape[0]-1] - cur_close) / cur_close

    record['stock'] = stock
    record['name'] = name

    df = df.append([record],ignore_index=True)

    week += 1

    df.to_csv(save + file_name, mode='a',header=False)
  return df

# %%
dirs[0]
# Out:
# 'MMM'

# %%
dirs = ['^GSPC']

for stock in dirs:
  path = os.path.join(root, stock)
  files = os.listdir(path)

  if stock+'_OHLC_1d.csv' not in files or stock+'_info.csv' not in files:
    continue
  #if stock == '^GSPC':
  #  continue

  # read
  raw_df = pd.read_csv(path+'/'+stock+'_OHLC_1d.csv')
  info  = pd.read_csv(path+'/'+stock+'_info.csv')

  if raw_df.shape[0] == 0:
    continue

  # Company Name
  info = info.set_index('Attribute')
  company_name_short = info.at['shortName','Value']

  # Convert to str to datetime
  raw_df['Date'] = raw_df['Date'].apply(drop_hours)
  raw_df['Date'] = pd.to_datetime(raw_df['Date'])

  if raw_df['Date'][0] > pd.to_datetime('2017-1-30'):
    continue

  print(stock, company_name_short)

  # features
  df_final = get_features(df, raw_df, company_name_short, stock)
  df_final.to_csv(save+'/'+stock+'_week_features.csv')
# Out:
# ^GSPC S&P 500

# %%
df
# Out:
# Empty DataFrame
# Columns: [name, stock, start_time, end_time, days, 成交量均值, 成交金额均值, 上周涨跌幅, 涨跌幅均值, 股价波动程度, 开收盘价方差, 未来一周的收益率]
# Index: []

# %% [markdown]
# # Random Sample 30 stocks

# %%
import pandas as pd
import numpy as np
import os

# google drive
from google.colab import drive
drive.mount('/content/drive') 

# ROOT
root = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/Data Preprocessing/dataset/"

# save
save = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/Data Preprocessing/"

os.chdir(root)
os.listdir(root)

dirs = os.listdir()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dirs[:477]
# Out:
# ['MMM_week_features.csv',
#  'AOS_week_features.csv',
#  'ABT_week_features.csv',
#  'ABBV_week_features.csv',
#  'ABMD_week_features.csv',
#  'ACN_week_features.csv',
#  'ATVI_week_features.csv',
#  'ADM_week_features.csv',
#  'ADBE_week_features.csv',
#  'AAP_week_features.csv',
#  'AMD_week_features.csv',
#  'AES_week_features.csv',
#  'AFL_week_features.csv',
#  'A_week_features.csv',
#  'APD_week_features.csv',
#  'AKAM_week_features.csv',
#  'ALK_week_features.csv',
#  'ALB_week_features.csv',
#  'ARE_week_features.csv',
#  'ALGN_week_features.csv',
#  'ALLE_week_features.csv',
#  'LNT_week_features.csv',
#  'ALL_week_features.csv',
#  'GOOGL_week_features.csv',
#  'GOOG_week_features.csv',
#  'MO_week_features.csv',
#  'AMZN_week_features.csv',
#  'AMCR_week_features.csv',
#  'AEE_week_features.csv',
#  'AAL_week_features.csv',
#  'AEP_week_features.csv',
#  'AXP_week_features.csv',
#  'AIG_week_features.csv',
#  'AMT_week_features.csv',
#  'AWK_week_features.csv',
#  'AMP_week_features.csv',
#  'ABC_week_features.csv',
#  'AME_week_features.csv',
#  'AMGN_week_features.csv',
#  'APH_week_features.csv',
#  'ADI_week_features.csv',
#  'ANSS_week_features.csv',
#  'AAPL_week_features.csv',
#  'ANET_week_features.csv',
#  'AJG_week_features.csv',
#  'AIZ_week_features.csv',
#  'T_week_features.csv',
#  'ATO_week_features.csv',
#  'ADSK_week_features.csv',
#  'ADP_week_features.csv',
#  'AZO_week_features.csv',
#  'AVB_week_features.csv',
#  'AVY_week_features.csv',
#  'BKR_week_features.csv',
#  'BAC_week_features.csv',
#  'BBWI_week_features.csv',
#  'BAX_week_features.csv',
#  'BDX_week_features.csv',
#  'BBY_week_features.csv',
#  'BIO_week_features.csv',
#  'TECH_week_features.csv',
#  'BIIB_week_features.csv',
#  'BLK_week_features.csv',
#  'BK_week_features.csv',
#  'BA_week_features.csv',
#  'BKNG_week_features.csv',
#  'BWA_week_features.csv',
#  'BXP_week_features.csv',
#  'BSX_week_features.csv',
#  'BMY_week_features.csv',
#  'AVGO_week_features.csv',
#  'BR_week_features.csv',
#  'BRO_week_features.csv',
#  'CHRW_week_features.csv',
#  'CDNS_week_features.csv',
#  'CZR_week_features.csv',
#  'CPB_week_features.csv',
#  'COF_week_features.csv',
#  'CAH_week_features.csv',
#  'KMX_week_features.csv',
#  'CCL_week_features.csv',
#  'CTLT_week_features.csv',
#  'CAT_week_features.csv',
#  'CBOE_week_features.csv',
#  'CBRE_week_features.csv',
#  'CDW_week_features.csv',
#  'CE_week_features.csv',
#  'CNC_week_features.csv',
#  'CNP_week_features.csv',
#  'CF_week_features.csv',
#  'CRL_week_features.csv',
#  'SCHW_week_features.csv',
#  'CHTR_week_features.csv',
#  'CVX_week_features.csv',
#  'CMG_week_features.csv',
#  'CB_week_features.csv',
#  'CHD_week_features.csv',
#  'CI_week_features.csv',
#  'CINF_week_features.csv',
#  'CTAS_week_features.csv',
#  'CSCO_week_features.csv',
#  'C_week_features.csv',
#  'CFG_week_features.csv',
#  'CTXS_week_features.csv',
#  'CLX_week_features.csv',
#  'CME_week_features.csv',
#  'CMS_week_features.csv',
#  'KO_week_features.csv',
#  'CTSH_week_features.csv',
#  'CL_week_features.csv',
#  'CMCSA_week_features.csv',
#  'CMA_week_features.csv',
#  'CAG_week_features.csv',
#  'COP_week_features.csv',
#  'ED_week_features.csv',
#  'STZ_week_features.csv',
#  'CPRT_week_features.csv',
#  'GLW_week_features.csv',
#  'COST_week_features.csv',
#  'CTRA_week_features.csv',
#  'CCI_week_features.csv',
#  'CSX_week_features.csv',
#  'CMI_week_features.csv',
#  'CVS_week_features.csv',
#  'DHI_week_features.csv',
#  'DHR_week_features.csv',
#  'DRI_week_features.csv',
#  'DVA_week_features.csv',
#  'DE_week_features.csv',
#  'DAL_week_features.csv',
#  'XRAY_week_features.csv',
#  'DVN_week_features.csv',
#  'DXCM_week_features.csv',
#  'FANG_week_features.csv',
#  'DLR_week_features.csv',
#  'DFS_week_features.csv',
#  'DISH_week_features.csv',
#  'DG_week_features.csv',
#  'DLTR_week_features.csv',
#  'D_week_features.csv',
#  'DPZ_week_features.csv',
#  'DOV_week_features.csv',
#  'DTE_week_features.csv',
#  'DUK_week_features.csv',
#  'DRE_week_features.csv',
#  'DD_week_features.csv',
#  'DXC_week_features.csv',
#  'EMN_week_features.csv',
#  'ETN_week_features.csv',
#  'EBAY_week_features.csv',
#  'ECL_week_features.csv',
#  'EIX_week_features.csv',
#  'EW_week_features.csv',
#  'EA_week_features.csv',
#  'LLY_week_features.csv',
#  'EMR_week_features.csv',
#  'ENPH_week_features.csv',
#  'ETR_week_features.csv',
#  'EOG_week_features.csv',
#  'EFX_week_features.csv',
#  'EQIX_week_features.csv',
#  'EQR_week_features.csv',
#  'ESS_week_features.csv',
#  'EL_week_features.csv',
#  'ETSY_week_features.csv',
#  'RE_week_features.csv',
#  'EVRG_week_features.csv',
#  'ES_week_features.csv',
#  'EXC_week_features.csv',
#  'EXPE_week_features.csv',
#  'EXPD_week_features.csv',
#  'EXR_week_features.csv',
#  'XOM_week_features.csv',
#  'FFIV_week_features.csv',
#  'FAST_week_features.csv',
#  'FRT_week_features.csv',
#  'FDX_week_features.csv',
#  'FIS_week_features.csv',
#  'FITB_week_features.csv',
#  'FRC_week_features.csv',
#  'FE_week_features.csv',
#  'FISV_week_features.csv',
#  'FLT_week_features.csv',
#  'FMC_week_features.csv',
#  'F_week_features.csv',
#  'FTNT_week_features.csv',
#  'FTV_week_features.csv',
#  'FBHS_week_features.csv',
#  'BEN_week_features.csv',
#  'FCX_week_features.csv',
#  'GPS_week_features.csv',
#  'GRMN_week_features.csv',
#  'IT_week_features.csv',
#  'GNRC_week_features.csv',
#  'GD_week_features.csv',
#  'GE_week_features.csv',
#  'GIS_week_features.csv',
#  'GM_week_features.csv',
#  'GPC_week_features.csv',
#  'GILD_week_features.csv',
#  'GPN_week_features.csv',
#  'GL_week_features.csv',
#  'GS_week_features.csv',
#  'HAL_week_features.csv',
#  'HBI_week_features.csv',
#  'HAS_week_features.csv',
#  'HCA_week_features.csv',
#  'PEAK_week_features.csv',
#  'HSIC_week_features.csv',
#  'HES_week_features.csv',
#  'HPE_week_features.csv',
#  'HLT_week_features.csv',
#  'HOLX_week_features.csv',
#  'HD_week_features.csv',
#  'HON_week_features.csv',
#  'HRL_week_features.csv',
#  'HST_week_features.csv',
#  'HWM_week_features.csv',
#  'HPQ_week_features.csv',
#  'HUM_week_features.csv',
#  'HBAN_week_features.csv',
#  'HII_week_features.csv',
#  'IBM_week_features.csv',
#  'IEX_week_features.csv',
#  'IDXX_week_features.csv',
#  'ITW_week_features.csv',
#  'ILMN_week_features.csv',
#  'INCY_week_features.csv',
#  'INTC_week_features.csv',
#  'ICE_week_features.csv',
#  'IFF_week_features.csv',
#  'IP_week_features.csv',
#  'IPG_week_features.csv',
#  'INTU_week_features.csv',
#  'ISRG_week_features.csv',
#  'IVZ_week_features.csv',
#  'IPGP_week_features.csv',
#  'IQV_week_features.csv',
#  'IRM_week_features.csv',
#  'JBHT_week_features.csv',
#  'JKHY_week_features.csv',
#  'J_week_features.csv',
#  'SJM_week_features.csv',
#  'JNJ_week_features.csv',
#  'JCI_week_features.csv',
#  'JPM_week_features.csv',
#  'JNPR_week_features.csv',
#  'K_week_features.csv',
#  'KEY_week_features.csv',
#  'KEYS_week_features.csv',
#  'KMB_week_features.csv',
#  'KIM_week_features.csv',
#  'KMI_week_features.csv',
#  'KLAC_week_features.csv',
#  'KHC_week_features.csv',
#  'KR_week_features.csv',
#  'LHX_week_features.csv',
#  'LH_week_features.csv',
#  'LRCX_week_features.csv',
#  'LW_week_features.csv',
#  'LVS_week_features.csv',
#  'LEG_week_features.csv',
#  'LDOS_week_features.csv',
#  'LEN_week_features.csv',
#  'LNC_week_features.csv',
#  'LIN_week_features.csv',
#  'LYV_week_features.csv',
#  'LKQ_week_features.csv',
#  'LMT_week_features.csv',
#  'L_week_features.csv',
#  'LOW_week_features.csv',
#  'LUMN_week_features.csv',
#  'LYB_week_features.csv',
#  'MTB_week_features.csv',
#  'MRO_week_features.csv',
#  'MPC_week_features.csv',
#  'MKTX_week_features.csv',
#  'MAR_week_features.csv',
#  'MMC_week_features.csv',
#  'MLM_week_features.csv',
#  'MAS_week_features.csv',
#  'MA_week_features.csv',
#  'MTCH_week_features.csv',
#  'MKC_week_features.csv',
#  'MCD_week_features.csv',
#  'MCK_week_features.csv',
#  'MDT_week_features.csv',
#  'MRK_week_features.csv',
#  'MET_week_features.csv',
#  'MTD_week_features.csv',
#  'MGM_week_features.csv',
#  'MCHP_week_features.csv',
#  'MU_week_features.csv',
#  'MSFT_week_features.csv',
#  'MAA_week_features.csv',
#  'MHK_week_features.csv',
#  'TAP_week_features.csv',
#  'MDLZ_week_features.csv',
#  'MPWR_week_features.csv',
#  'MNST_week_features.csv',
#  'MCO_week_features.csv',
#  'MS_week_features.csv',
#  'MSI_week_features.csv',
#  'MSCI_week_features.csv',
#  'NDAQ_week_features.csv',
#  'NTAP_week_features.csv',
#  'NFLX_week_features.csv',
#  'NWL_week_features.csv',
#  'NEM_week_features.csv',
#  'NWSA_week_features.csv',
#  'NWS_week_features.csv',
#  'NEE_week_features.csv',
#  'NLSN_week_features.csv',
#  'NKE_week_features.csv',
#  'NI_week_features.csv',
#  'NSC_week_features.csv',
#  'NTRS_week_features.csv',
#  'NOC_week_features.csv',
#  'NLOK_week_features.csv',
#  'NCLH_week_features.csv',
#  'NRG_week_features.csv',
#  'NUE_week_features.csv',
#  'NVDA_week_features.csv',
#  'NVR_week_features.csv',
#  'NXPI_week_features.csv',
#  'ORLY_week_features.csv',
#  'OXY_week_features.csv',
#  'ODFL_week_features.csv',
#  'OMC_week_features.csv',
#  'OKE_week_features.csv',
#  'ORCL_week_features.csv',
#  'PCAR_week_features.csv',
#  'PKG_week_features.csv',
#  'PH_week_features.csv',
#  'PAYX_week_features.csv',
#  'PAYC_week_features.csv',
#  'PYPL_week_features.csv',
#  'PENN_week_features.csv',
#  'PNR_week_features.csv',
#  'PEP_week_features.csv',
#  'PKI_week_features.csv',
#  'PFE_week_features.csv',
#  'PM_week_features.csv',
#  'PSX_week_features.csv',
#  'PNW_week_features.csv',
#  'PXD_week_features.csv',
#  'PNC_week_features.csv',
#  'POOL_week_features.csv',
#  'PPG_week_features.csv',
#  'PPL_week_features.csv',
#  'PFG_week_features.csv',
#  'PG_week_features.csv',
#  'PGR_week_features.csv',
#  'PLD_week_features.csv',
#  'PRU_week_features.csv',
#  'PTC_week_features.csv',
#  'PEG_week_features.csv',
#  'PSA_week_features.csv',
#  'PHM_week_features.csv',
#  'PVH_week_features.csv',
#  'QRVO_week_features.csv',
#  'QCOM_week_features.csv',
#  'PWR_week_features.csv',
#  'DGX_week_features.csv',
#  'RL_week_features.csv',
#  'RJF_week_features.csv',
#  'RTX_week_features.csv',
#  'O_week_features.csv',
#  'REG_week_features.csv',
#  'REGN_week_features.csv',
#  'RF_week_features.csv',
#  'RSG_week_features.csv',
#  'RMD_week_features.csv',
#  'RHI_week_features.csv',
#  'ROK_week_features.csv',
#  'ROL_week_features.csv',
#  'ROP_week_features.csv',
#  'ROST_week_features.csv',
#  'RCL_week_features.csv',
#  'SPGI_week_features.csv',
#  'CRM_week_features.csv',
#  'SBAC_week_features.csv',
#  'SLB_week_features.csv',
#  'STX_week_features.csv',
#  'SEE_week_features.csv',
#  'SRE_week_features.csv',
#  'NOW_week_features.csv',
#  'SHW_week_features.csv',
#  'SPG_week_features.csv',
#  'SWKS_week_features.csv',
#  'SNA_week_features.csv',
#  'SO_week_features.csv',
#  'LUV_week_features.csv',
#  'SWK_week_features.csv',
#  'SBUX_week_features.csv',
#  'STT_week_features.csv',
#  'STE_week_features.csv',
#  'SYK_week_features.csv',
#  'SIVB_week_features.csv',
#  'SYF_week_features.csv',
#  'SNPS_week_features.csv',
#  'SYY_week_features.csv',
#  'TMUS_week_features.csv',
#  'TROW_week_features.csv',
#  'TTWO_week_features.csv',
#  'TPR_week_features.csv',
#  'TGT_week_features.csv',
#  'TEL_week_features.csv',
#  'TDY_week_features.csv',
#  'TFX_week_features.csv',
#  'TER_week_features.csv',
#  'TSLA_week_features.csv',
#  'TXN_week_features.csv',
#  'TXT_week_features.csv',
#  'COO_week_features.csv',
#  'HIG_week_features.csv',
#  'HSY_week_features.csv',
#  'MOS_week_features.csv',
#  'TRV_week_features.csv',
#  'DIS_week_features.csv',
#  'TMO_week_features.csv',
#  'TJX_week_features.csv',
#  'TSCO_week_features.csv',
#  'TT_week_features.csv',
#  'TDG_week_features.csv',
#  'TRMB_week_features.csv',
#  'TFC_week_features.csv',
#  'TWTR_week_features.csv',
#  'TYL_week_features.csv',
#  'TSN_week_features.csv',
#  'USB_week_features.csv',
#  'UDR_week_features.csv',
#  'ULTA_week_features.csv',
#  'UAA_week_features.csv',
#  'UA_week_features.csv',
#  'UNP_week_features.csv',
#  'UAL_week_features.csv',
#  'UPS_week_features.csv',
#  'URI_week_features.csv',
#  'UNH_week_features.csv',
#  'UHS_week_features.csv',
#  'VLO_week_features.csv',
#  'VTR_week_features.csv',
#  'VRSN_week_features.csv',
#  'VRSK_week_features.csv',
#  'VZ_week_features.csv',
#  'VRTX_week_features.csv',
#  'VFC_week_features.csv',
#  'VTRS_week_features.csv',
#  'V_week_features.csv',
#  'VNO_week_features.csv',
#  'VMC_week_features.csv',
#  'WRB_week_features.csv',
#  'GWW_week_features.csv',
#  'WAB_week_features.csv',
#  'WBA_week_features.csv',
#  'WMT_week_features.csv',
#  'WM_week_features.csv',
#  'WAT_week_features.csv',
#  'WEC_week_features.csv',
#  'WFC_week_features.csv',
#  'WELL_week_features.csv',
#  'WST_week_features.csv',
#  'WDC_week_features.csv',
#  'WU_week_features.csv',
#  'WRK_week_features.csv',
#  'WY_week_features.csv',
#  'WHR_week_features.csv',
#  'WMB_week_features.csv',
#  'WYNN_week_features.csv',
#  'XEL_week_features.csv',
#  'XYL_week_features.csv',
#  'YUM_week_features.csv',
#  'ZBRA_week_features.csv',
#  'ZBH_week_features.csv',
#  'ZION_week_features.csv',
#  'ZTS_week_features.csv']

# %%
from random import sample
sampled_list = sample(dirs, 30)
sampled_list = [i.split('_')[0] for i in sampled_list]
sampled_list
# Out:
# ['AES',
#  'DRI',
#  'LVS',
#  'ZION',
#  'TJX',
#  'KMX',
#  'DVA',
#  'PYPL',
#  'INTU',
#  'ADI',
#  'HIG',
#  'MCHP',
#  'GPN',
#  'MO',
#  'SRE',
#  'WELL',
#  'TSCO',
#  'NEM',
#  'REG',
#  'GM',
#  'K',
#  'VTRS',
#  'BXP',
#  'UHS',
#  'JCI',
#  'AKAM',
#  'IEX',
#  'ANSS',
#  'V',
#  'LUV']

# %% [markdown]
# # StandardScaler

# %%
import pandas as pd
import numpy as np
import os

from sklearn.preprocessing import StandardScaler

# google drive
from google.colab import drive
drive.mount('/content/drive') 

# ROOT
read = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/Data Preprocessing/dataset/"

# save
save = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/Data Preprocessing/dataset/Sampled_30_dataset/rescaled_data/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sampled_list=['^GSPC']
for stock in sampled_list:
  print(stock)
  # read
  df = pd.read_csv(read+stock+'_week_features.csv')
  # drop inf and nan
  df = df.replace([np.inf,-np.inf],np.nan).dropna()

  cut = ['成交量均值','成交金额均值','上周涨跌幅','涨跌幅均值','股价波动程度','开收盘价方差','未来一周的收益率']

  # cols to rescale
  std_df = df[cut]

  # cut
  df = df[['name','stock','start_time','end_time','days']].reset_index()

  # rescaler
  scaler = StandardScaler()
  scaler.fit(std_df)
  result = pd.DataFrame(scaler.transform(std_df), columns=cut)

  # concat
  df = pd.concat([df[['name','stock','start_time','end_time','days']], result], axis=1)

  # save
  df.to_csv(save+stock+'_week_features_rescaled.csv')
# Out:
# ^GSPC

# %%
a = pd.DataFrame(scaler.transform(std_df), columns=['成交量均值','成交金额均值','上周涨跌幅','涨跌幅均值','股价波动程度','开收盘价方差','未来一周的收益率'])
a
# Out:
#         成交量均值    成交金额均值     上周涨跌幅     涨跌幅均值    股价波动程度    开收盘价方差  未来一周的收益率
# 0   -0.372663 -0.448707 -0.037860  0.365111 -0.557650 -0.381331 -0.018511
# 1   -0.399613 -0.508696  0.387030  0.460150 -0.635223 -0.503229  0.609192
# 2    0.282212  0.601274  0.387511  1.223114  1.523516  1.322448  0.069606
# 3   -0.271594 -0.245482  1.297821  0.213624 -0.887959 -0.531587  0.668596
# 4   -0.434147 -0.473104  0.226223  0.678275 -0.107521 -0.257258  0.920162
# ..        ...       ...       ...       ...       ...       ...       ...
# 293 -0.434759 -0.870276 -1.068083  0.023026 -0.405714 -0.463917 -0.400224
# 294 -0.562784 -1.041082  0.023898 -0.425020 -0.586651 -0.479894  0.856012
# 295 -0.345209 -0.764908 -0.451713  1.227379 -0.005882 -0.410905 -1.817783
# 296  0.064190 -0.324167  1.039057 -2.343049  1.620589  0.238612 -1.477891
# 297 -0.059917 -0.574425 -2.487748 -2.399860  1.905129  0.421028 -0.721001
#
# [298 rows x 7 columns]

# %%
df = df.replace([np.inf,-np.inf],np.nan).dropna()
df = df[['name','stock','start_time','end_time','days']].reset_index()

# %%
pd.concat([df[['name','stock','start_time','end_time','days']], a], axis=1)
# Out:
#                            name stock                     start_time  \
# 0    Southwest Airlines Company   LUV  2017-01-09 00:00:00.000000000
# 1    Southwest Airlines Company   LUV  2017-01-16 00:00:00.000000000
# 2    Southwest Airlines Company   LUV  2017-01-23 00:00:00.000000000
# 3    Southwest Airlines Company   LUV  2017-01-30 00:00:00.000000000
# 4    Southwest Airlines Company   LUV  2017-02-06 00:00:00.000000000
# ..                          ...   ...                            ...
# 293  Southwest Airlines Company   LUV  2022-08-22 00:00:00.000000000
# 294  Southwest Airlines Company   LUV  2022-08-29 00:00:00.000000000
# 295  Southwest Airlines Company   LUV  2022-09-05 00:00:00.000000000
# 296  Southwest Airlines Company   LUV  2022-09-12 00:00:00.000000000
# 297  Southwest Airlines Company   LUV  2022-09-19 00:00:00.000000000
#
#                           end_time  days     成交量均值    成交金额均值     上周涨跌幅  \
# 0    2017-01-15 23:59:59.999999999     5 -0.372663 -0.448707 -0.037860
# 1    2017-01-22 23:59:59.999999999     4 -0.399613 -0.508696  0.387030
# 2    2017-01-29 23:59:59.999999999     5  0.282212  0.601274  0.387511
# 3    2017-02-05 23:59:59.999999999     5 -0.271594 -0.245482  1.297821
# 4    2017-02-12 23:59:59.999999999     5 -0.434147 -0.473104  0.226223
# ..                             ...   ...       ...       ...       ...
# 293  2022-08-28 23:59:59.999999999     5 -0.434759 -0.870276 -1.068083
# 294  2022-09-04 23:59:59.999999999     5 -0.562784 -1.041082  0.023898
# 295  2022-09-11 23:59:59.999999999     4 -0.345209 -0.764908 -0.451713
# 296  2022-09-18 23:59:59.999999999     5  0.064190 -0.324167  1.039057
# 297  2022-09-25 23:59:59.999999999     5 -0.059917 -0.574425 -2.487748
#
#         涨跌幅均值    股价波动程度    开收盘价方差  未来一周的收益率
# 0    0.365111 -0.557650 -0.381331 -0.018511
# 1    0.460150 -0.635223 -0.503229  0.609192
# 2    1.223114  1.523516  1.322448  0.069606
# 3    0.213624 -0.887959 -0.531587  0.668596
# 4    0.678275 -0.107521 -0.257258  0.920162
# ..        ...       ...       ...       ...
# 293  0.023026 -0.405714 -0.463917 -0.400224
# 294 -0.425020 -0.586651 -0.479894  0.856012
# 295  1.227379 -0.005882 -0.410905 -1.817783
# 296 -2.343049  1.620589  0.238612 -1.477891
# 297 -2.399860  1.905129  0.421028 -0.721001
#
# [298 rows x 12 columns]

# %% [markdown]
# # concat

# %%
import pandas as pd
import numpy as np
import os

# google drive
from google.colab import drive
drive.mount('/content/drive') 

# ROOT
root = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/Data Preprocessing/dataset/Sampled_30_dataset/rescaled_data"

# save
save = "/content/drive/MyDrive/BDT SEM 1/MSBD 5001/Data Preprocessing/dataset/Sampled_30_dataset"

os.chdir(root)
os.listdir(root)

dirs = os.listdir()
dirs
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['AES_week_features_rescaled.csv',
#  'DRI_week_features_rescaled.csv',
#  'LVS_week_features_rescaled.csv',
#  'ZION_week_features_rescaled.csv',
#  'TJX_week_features_rescaled.csv',
#  'KMX_week_features_rescaled.csv',
#  'DVA_week_features_rescaled.csv',
#  'PYPL_week_features_rescaled.csv',
#  'INTU_week_features_rescaled.csv',
#  'ADI_week_features_rescaled.csv',
#  'HIG_week_features_rescaled.csv',
#  'MCHP_week_features_rescaled.csv',
#  'GPN_week_features_rescaled.csv',
#  'MO_week_features_rescaled.csv',
#  'SRE_week_features_rescaled.csv',
#  'WELL_week_features_rescaled.csv',
#  'TSCO_week_features_rescaled.csv',
#  'NEM_week_features_rescaled.csv',
#  'REG_week_features_rescaled.csv',
#  'GM_week_features_rescaled.csv',
#  'K_week_features_rescaled.csv',
#  'VTRS_week_features_rescaled.csv',
#  'BXP_week_features_rescaled.csv',
#  'UHS_week_features_rescaled.csv',
#  'JCI_week_features_rescaled.csv',
#  'AKAM_week_features_rescaled.csv',
#  'IEX_week_features_rescaled.csv',
#  'ANSS_week_features_rescaled.csv',
#  'V_week_features_rescaled.csv',
#  'LUV_week_features_rescaled.csv']

# %%
dfs=[]
for file in dirs:
  df = pd.read_csv(root+'/'+file, index_col=0)
  dfs.append(df)

df_all = pd.concat(dfs, ignore_index=False)

# %%
df_all.to_csv(save+'/'+'30_stocks_weekly_features.csv')

# %%
df_all[['name','stock']].drop_duplicates(subset=None,keep='first',inplace=False).to_csv(save+'/'+'selected_30_stocks.csv')
